# %% [markdown]
# # Compressor de Imagens

# %% [markdown]
# Alunos:
#  - Daniel Souza de Campos - 2018054664
#  - Letícia da Silva Macedo Alves - 2018054443

# %%
# %matplotlib inline
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
def retiraDoisBitsMenosSignificativos(img):
    # 2 bits
    return img & 0xFC

# %%
def compressImage(img):
    return retiraDoisBitsMenosSignificativos(img)

# %%
# original
tigre = cv2.imread('tigre.jpg',0)
plt.title('Original Image')
plt.imshow(img1, cmap = 'gray')
plt.show()

# %%
plt.title('Tigre menos dois bits menos significativos')
plt.imshow(compressImage(tigre), cmap = 'gray')
plt.show()

# %%
# original
casa = cv2.imread('casa.jpg',0)
plt.title('Original Image')
plt.imshow(casa, cmap = 'gray')
plt.show()

# %%
plt.title('Casa menos dois bits menos significativos')
plt.imshow(compressImage(casa), cmap = 'gray')
plt.show()
